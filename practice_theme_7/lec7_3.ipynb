# %% [markdown]
# ## Автоматический доступ к данным

# %%
# !pip install kaggle
# Out:
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73049 sha256=4bce576d510795ea329c9a67c42f0a3937d2690fb74adeec6d29797f44e5a161
#   Stored in directory: c:\users\mob19\appdata\local\pip\cache\wheels\ac\b2\c3\fa4706d469b5879105991d1c8be9a3c2ef329ba9fe2ce5085e
# Successfully built kaggle
# ...
# WARNING: Ignoring invalid distribution -lotly (c:\users\mob19\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\mob19\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\mob19\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\mob19\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\mob19\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\mob19\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\mob19\anaconda\lib\site-packages)

# %%
# %pwd
# Out:
# 'c:\\Users\\mob19\\OneDrive\\Рабочий стол\\ranepa_python_3\\practice_theme_7'

# %%
# !kaggle datasets list -s titanic

# %%
# !kaggle datasets download broaniki/titanic
# Out:
# ...
#   0%|          | 0.00/717k [00:00<?, ?B/s]
# 100%|██████████| 717k/717k [00:03<00:00, 190kB/s]
# 100%|██████████| 717k/717k [00:03<00:00, 190kB/s]

# %%
import pandas as pd
tt = pd.read_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\titanic\\input\\train.csv')
display(tt)
# ttg = pd.read_csv("C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\titanic\input\\gender_submission.csv")
# display(ttg)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# %cd C:\\Users\\mob19\\OneDrive\\Рабочий стол
# Out:
# C:\Users\mob19\OneDrive\Рабочий стол

# %%
# !kaggle competitions download -c titanic --force

# %%
import pandas as pd
tt = pd.read_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\titanic\\input\\train.csv')
tt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# !dir

# %% [markdown]
# ## Данные по соревнованию FIFA

# %%
# !kaggle competitions files -c fifa2019wages
# Out:
# name                                      size  creationDate
# ---------------------------------------  -----  -------------------
# SampleSol.csv                             60KB  2020-01-02 01:03:11
# FIFA Data set Competition STAT 101A.pdf  349KB  2020-01-02 01:03:11
# FifaNoY.csv                                2MB  2020-01-02 01:03:11
# FifaTrainNew.csv                           4MB  2020-01-02 01:03:11
# SampleSol2.csv                            60KB  2020-01-02 01:03:11

# %%
! kaggle competitions download -c fifa2019wages -f FifaTrainNew.csv
# Out:
# ...
#   0%|          | 0.00/1.18M [00:00<?, ?B/s]
#  84%|████████▍ | 1.00M/1.18M [00:00<00:00, 1.69MB/s]
# 100%|██████████| 1.18M/1.18M [00:00<00:00, 1.80MB/s]

# %%
ff19 = pd.read_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\FifaTrainNew.csv.zip')
ff19
# Out:
#           Ob  WageNew  Age     Nationality  Overall  Potential  \
# 0          1    26735   25         Austria       77         80
# 1          2     3709   22    Saudi Arabia       58         67
# 2          3     4720   29         Austria       66         66
# 3          4    31062   24          Sweden       71         73
# 4          5    43797   26        Colombia       80         84
# ...      ...      ...  ...             ...      ...        ...
# 12740  12741    12076   28  Czech Republic       71         71
# 12741  12742     1483   23         Germany       60         69
# 12742  12743     3212   19    Saudi Arabia       56         72
# 12743  12744     1549   18     Ivory Coast       61         79
# 12744  12745     4173   22     Switzerland       65         77
#
#                              Club  Special Preferred Foot  \
# 0                     FC Augsburg     1971           Left
# 1                        Al Wehda     1510          Right
# ...

# %% [markdown]
# ## Competition 2022 Data

# %%
! kaggle datasets download -d stefanoleone992/fifa-22-compete-player-dataset
# Out:
# 403 - Forbidden

# %% [markdown]
# ## Нативная загрузка данных на питоне

# %%
import kaggle

# %%
kaggle.api.authenticate()
kaggle.api.dataset_download_file('stefanoleone992/fifa-22-complete-player-dataset', file_name = 'players_21.csv', path='C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data')
# Out:
# False

# %%
ff21 = pd.read_csv("C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\players_21.csv.zip")
ff21.head()
ff21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(16), int64(44), object(50)
# memory usage: 15.9+ MB

# %%
# ff21.describe()
# ff21.columns
# ff19
display(ff21)
display(ff21)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         188545  https://sofifa.com/player/188545/robert-lewand...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 18939     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18940     257933  https://sofifa.com/player/257933/wenzhuo-huang...
# 18941     257936   https://sofifa.com/player/257936/yue-song/210002
# 18942     258736  https://sofifa.com/player/258736/vani-da-silva...
# 18943     258760  https://sofifa.com/player/258760/ben-hough/210002
#
#               short_name                            long_name  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %% [markdown]
# ## Загрузка нескольких файлов

# %%
import kaggle
kaggle.api.authenticate()
kaggle.api.dataset_download_files('stefanoleone992/fifa-22-complete-player-dataset', path='C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data')
