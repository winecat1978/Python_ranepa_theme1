# %% [markdown]
# ### Чтение данных в объекты Python

# %%
# import pandas as pd
# d = pd.read_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\data.log.csv', sep="\\t ")
# pd.options.display.max_rows = 1002
# # pd.set_option('display.max_rows', 1002)
# d

# %% [markdown]
# ### Подготовить данные в удобном формате

# %%
import pandas as pd
d = pd.read_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\data.log.csv')
pd.options.display.max_rows = 1002
# pd.set_option('display.max_rows', 1002)
# d
# d = pd.read_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\data.log.csv', sep="\\t", header=2)
# Переименовать колонки
# Обращать внимание на точное исходное название колонок 
# Notepad++ || Посмотреть все символы
d_clean=d.rename(columns={'id':'user_id', 'time':'Time', 'bet':'Stavka','win':'result'})
# display(d_clean)
# ИЛИ
# d.rename(columns={'id':'user_id', 'time':'Time', 'bet':'Stavka','win':'result'}, inplace=True)

# d_clean[['Stavka', 'result']]
d_clean.to_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\data.log.csv', index=False)
# display(d_clean[['user_id','Stavka']]) # вывод конкретных столбцов
# display(d.Stavka) # вывод конкретного стоблца (аналогичный)
# display(d.loc[:,'user_id':'result']) # вывод столбцов с... по... какой-то 
# display(d.iloc[:,3:6]) # вывод столбцов по их индексам (не включительно для конца)
# display(d.iloc[::2,3:6]) # вывод строк через одну [проход по строкам, проход по столбцам]
# display(d.iloc[1:51,3:6]) # первые 50 строк
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5       156789.0
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14      145732.0
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19       98753.0
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29     1678321.0
# 30           NaN
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# 36           NaN
# 37           NaN
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# 44           NaN
# 45           NaN
# 46           NaN
# 47           NaN
# 48           NaN
# 49           NaN
# 50           NaN
# 51           NaN
# ...

# %% [markdown]
# ## Индексация серии

# %%
bet = d.Stavka.loc[1:10] # берем столбец по названию
bet
# Out:
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5     156789.0
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# Name: Stavka, dtype: float64

# %%
# d = pd.read_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\data.log.csv', index_col='Unnamed: 0') # Удалить колонку 
d = pd.read_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\data.log.csv', index_col=0, usecols=['Stavka', 'result']) #  Index=False - Без индексов 
# d.columns
# d.index # Multiindex
d
# Out:
#               result
# Stavka
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# 156789.0         NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# 145732.0   1987653.0
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# 98753.0          NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# 1678321.0  9876543.0
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# ...

# %%
# d = pd.read_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\data.log.csv', index_col='Unnamed: 0') # Удалить колонку 
d = pd.read_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\data.log.csv', index_col=0, usecols=['Stavka', 'result']) #  Index=False - Без индексов 
# d.columns
# d.index # Multiindex
d
# Out:
#               result
# Stavka
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# 156789.0         NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# 145732.0   1987653.0
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# 98753.0          NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# 1678321.0  9876543.0
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# NaN              NaN
# ...

# %% [markdown]
# ## Извлечение нужных данных

# %%
d.shape
# Out:
# (1000, 4)

# %%
# d['result']
# d.reset_index(inplace=True)
# display(d)
# Out:
#         Stavka     result
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN
# 5     156789.0        NaN
# 6          NaN        NaN
# 7          NaN        NaN
# 8          NaN        NaN
# 9          NaN        NaN
# 10         NaN        NaN
# 11         NaN        NaN
# 12         NaN        NaN
# 13         NaN        NaN
# 14    145732.0  1987653.0
# 15         NaN        NaN
# 16         NaN        NaN
# 17         NaN        NaN
# 18         NaN        NaN
# 19     98753.0        NaN
# 20         NaN        NaN
# 21         NaN        NaN
# 22         NaN        NaN
# 23         NaN        NaN
# 24         NaN        NaN
# 25         NaN        NaN
# 26         NaN        NaN
# 27         NaN        NaN
# 28         NaN        NaN
# 29   1678321.0  9876543.0
# 30         NaN        NaN
# 31         NaN        NaN
# 32         NaN        NaN
# 33         NaN        NaN
# ...

# %%
d.reset_index(inplace=True)
display(d)
# Out:
#      index     Stavka     result
# 0        0        NaN        NaN
# 1        1        NaN        NaN
# 2        2        NaN        NaN
# 3        3        NaN        NaN
# 4        4        NaN        NaN
# 5        5   156789.0        NaN
# 6        6        NaN        NaN
# 7        7        NaN        NaN
# 8        8        NaN        NaN
# 9        9        NaN        NaN
# 10      10        NaN        NaN
# 11      11        NaN        NaN
# 12      12        NaN        NaN
# 13      13        NaN        NaN
# 14      14   145732.0  1987653.0
# 15      15        NaN        NaN
# 16      16        NaN        NaN
# 17      17        NaN        NaN
# 18      18        NaN        NaN
# 19      19    98753.0        NaN
# 20      20        NaN        NaN
# 21      21        NaN        NaN
# 22      22        NaN        NaN
# 23      23        NaN        NaN
# 24      24        NaN        NaN
# 25      25        NaN        NaN
# 26      26        NaN        NaN
# ...

# %%
dp = pd.read_csv('C:\\Users\\mob19\\OneDrive\\Рабочий стол\\data\\data.log.csv', usecols=['Stavka','result'])
# dp.drop(columns='Unnamed:0.1',axis=1)
dp
# Out:
#         Stavka     result
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN
# 5     156789.0        NaN
# 6          NaN        NaN
# 7          NaN        NaN
# 8          NaN        NaN
# 9          NaN        NaN
# 10         NaN        NaN
# 11         NaN        NaN
# 12         NaN        NaN
# 13         NaN        NaN
# 14    145732.0  1987653.0
# 15         NaN        NaN
# 16         NaN        NaN
# 17         NaN        NaN
# 18         NaN        NaN
# 19     98753.0        NaN
# 20         NaN        NaN
# 21         NaN        NaN
# 22         NaN        NaN
# 23         NaN        NaN
# 24         NaN        NaN
# 25         NaN        NaN
# 26         NaN        NaN
# 27         NaN        NaN
# 28         NaN        NaN
# 29   1678321.0  9876543.0
# 30         NaN        NaN
# 31         NaN        NaN
# 32         NaN        NaN
# 33         NaN        NaN
# ...

# %%
import numpy

# %%
mask = dp['result'].notna() # ищет ненулевые значения в выигрыше
mask

wins  = dp['result'][mask] # накладываем маску на колонку "выигрыш"
# wins.mean() # среднее значение выигрыша
wins.sum() # СКОЛЬКО всего выиграли
wins.shape # сколько человек выиграло
# Out:
# (138,)

# %%
dp.reset_index(inplace=True)
display(dp)
dp.shape
# Out:
#                                user_id     Stavka     result
# 0     Запись пользователя ? - user_919        NaN        NaN
# 1     Запись пользователя ? - user_973        NaN        NaN
# 2     Запись пользователя ? - user_903        NaN        NaN
# 3     Запись пользователя ? - user_954        NaN        NaN
# 4     Запись пользователя ? - user_954        NaN        NaN
# 5     Запись пользователя ? - user_917   156789.0        NaN
# 6     Запись пользователя ? - user_900        NaN        NaN
# 7     Запись пользователя ? - user_980        NaN        NaN
# 8     Запись пользователя ? - user_906        NaN        NaN
# 9     Запись пользователя ? - user_952        NaN        NaN
# 10    Запись пользователя ? - user_972        NaN        NaN
# 11    Запись пользователя ? - user_966        NaN        NaN
# 12    Запись пользователя ? - user_964        NaN        NaN
# 13    Запись пользователя ? - user_978        NaN        NaN
# ...
